# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from datetime import datetime, date
from pandas import Series, DataFrame

# %%
# Body Parts
head = ['Boca (Inclusive Labi','Boca (Inclusive Labios, Dentes, Lingua, Garga','Cabeca, Nic','Cabeca, Partes Multi','Cabeca, Partes Multiplas (Qualquer Combinacao','Cranio (Inclusive En','Face, Partes Multipl','Cranio (Inclusive Encefalo)','Face, Partes Multiplas (Qualquer Combinacao D','Mandibula (Inclusive','Mandibula (Inclusive Queixo)','Nariz (Inclusive Fos','Nariz (Inclusive Fossas Nasais, Seios da Face','Olho (Inclusive Nerv','Olho (Inclusive Nervo Otico e Visao)','Ouvido (Externo, Med','Pescoco','Ouvido (Externo, Medio, Interno, Audicao e Eq']
lowerLimb = ['Artelho','Articulacao do Torno', 'Articulacao do Tornozelo','Coxa', 'Joelho', 'Membros Inferiores,','Membros Inferiores, Nic','Membros Inferiores, Partes Multiplas (Qualque','Pe (Exceto Artelhos)','Perna (Entre O Torno', 'Perna (Do Tornozelo,','Perna (Do Tornozelo, Exclusive, ao Joelho, Ex','Perna (Entre O Tornozelo e a Pelvis)']
upperLimb = ['Antebraco (Entre O P','Antebraco (Entre O Punho e O Cotovelo)','Braco (Entre O Punho', 'Braco (Acima do Coto','Braco (Acima do Cotovelo)','Braco (Entre O Punho a O Ombro)','Cotovelo','Dedo', 'Mao (Exceto Punho ou', 'Mao (Exceto Punho ou Dedos)' ,'Membros Superiores,','Membros Superiores, Nic' ,'Membros Superiores, Partes Multiplas (Qualque','Ombro', 'Punho']
multipleParts = ['Partes Multiplas - A', 'Partes Multiplas - Aplica-Se Quando Mais de U', 'Localizacao da Lesao, Nic', 'Localizacao da Lesao']
bodySystems = ['Aparelho Circulatori','Aparelho Circulatorio','Aparelho Digestivo','Aparelho Genito-Urinario','Aparelho Genito-Urin','Aparelho Respiratorio','Sistema Musculo-Esqu','Sistema Nervoso', 'Aparelho Respiratori','Sistema Musculo-Esqueletic','Sistema Musculo-Esqueletico','Sistemas e Aparelhos','Sistemas e Aparelhos - Aplica-Se Quando O Fun','Sistemas e Aparelhos, Nic']
torso = ['Abdome (Inclusive Or','Abdome (Inclusive Orgaos Internos)','Dorso (Inclusive Mus', 'Dorso (Inclusive Musculos Dorsais, Coluna e M','Quadris (Inclusive P','Quadris (Inclusive Pelvis, Orgaos Pelvicos E','Torax (Inclusive Org','Torax (Inclusive Orgaos Internos)', 'Tronco, Nic', 'Tronco, Parte Multip', 'Tronco, Parte Multiplas (Qualquer Combinacao']

arrayNameGroupPart = ['Cabeca',  'Membros_Inferiores','Membros_Superiores', 'Partes_Multiplas', 'Sistemas_Aparelhos', 'Tronco']

# %%
# Regions
north = ['Acre','Amapá','AmapÃ¡','AmapÃÂ¡','AmapÃ¯Â¿Â½','Amazonas','Rondônia','RondÃ´nia','RondÃ¯Â¿Â½nia','RondÃÂ´nia','Roraima','Tocantins','Pará', 'ParÃ¡']
northeast = ['Alagoas','Bahia','Ceará','CearÃ¡','CearÃ¯Â¿Â½','CearÃÂ¡','Cearï¿½','Maranhão','MaranhÃ£o','MaranhÃ¯Â¿Â½o','MaranhÃÂ£o','Paraíba','ParaÃ­ba','ParaÃ¯Â¿Â½ba','ParaÃÂ­ba','Pernambuco','Piauí','PiauÃ­','PiauÃ¯Â¿Â½','PiauÃÂ­','Rio Grande Norte','Rio Grande do Norte','Sergipe', 'ParÃ¯Â¿Â½']
southeast = ['Espirito Santo','EspÃ¯Â¿Â½rito Santo','EspÃÂ­rito Santo','EspÃ­rito Santo','Minas Gerais','Rio de Janeiro','São Paulo','SÃ£o Paulo', 'SÃ¯Â¿Â½o Paulo','SÃÂ£o Paulo']
midwest = ['Distrito Federal','Goiás','GoiÃÂ¡s','GoiÃ¡s','GoiÃ¯Â¿Â½s','Mato Grosso do Sul','Mato Grosso']
south = ['Paraná','Rio Grande do Sul','Santa Catarina', 'ParÃÂ¡','ParanÃ¡','ParanÃÂ¡','ParanÃ¯Â¿Â½']
arrayRegions = ['Norte', 'Nordeste', 'Centro_Oeste', 'Sul', 'Sudeste']

# %%
# Nature_Injury
arrayAmputacao = ['Amputacao ou Enucleacao', 'Amputacao ou Enuclea']
arrayAsfixia = ['Asfixia, Estrangulamento, Afogamento', 'Asfixia, Estrangulam']
arrayChoque = ['Choque Eletrico e El','Choque Eletrico e Eletroplessao (Eletrocuss']
arrayConcussao = ['Concussao Cerebral']
arrayCongelamento = ['Congelamento, Geladu','Congelamento, Geladura e Outros Efeitos Da']
arrayContusao = ['Contusao, Esmagament', 'Contusao, Esmagamento (Superficie Cutanea I']
arrayCortes = ['Corte, Laceracao, Ferida Contusa, Punctura', 'Corte, Laceracao, Fe']
arrayDermatose = ['Dermatose (Erupcao, Inflamacao da Pele, Inc', 'Dermatose (Erupcao,']
arrayDistensao=['Distensao, Torcao','Distensao, Torcao']
arrayDoencas = ['Doenca Contagiosa ou Infecciosa (Tuberculos','Doenca Contagiosa ou','Doenca, Nic']
arrayRadiacao = ['Efeito de Radiacao (', 'Efeito de Radiacao (Imediato) - Queimadura', 'Efeito de Radiacao (Mediato) - Queimadura D']
arrayEnvenenamento =['Envenenamento Sistem', 'Envenenamento Sistemico - Condicao Morbida']  
arrayEscoriacao = ['Escoriacao, Abrasao','Escoriacao, Abrasao (Ferimento Superficial)']
arrayEsforco = ['Esforco Excessivo ao','Esforco Excessivo ao Empurrar ou Puxar Objeto','Esforco Excessivo ao Empurrar ou Puxar Objeto']
arrayFratura = ['Fratura']
arrayHernia = ['Hernia de Qualquer N','Hernia de Qualquer Natureza, Ruptura']
arrayInflamacao = ['Inflamacao de Articu', 'Inflamacao de Articulacao, Tendao ou Muscul']
arrayIntermacao = ['Intermacao, Insolaca','Intermacao, Insolacao, Caibra, Exaustao e O']
arrayLesoes = ['Lesoes Multiplas', 'Lesao Imediata','Lesao Imediata, Nic', 'Outras Lesoes, Nic']
arrayLuxacao = ['Luxacao']
arrayPerdaSentidos = ['Perda ou Diminuicao','Perda ou Diminuicao Mediatas de Sentido (Au','Perda ou Diminuicao de Sentido (Audicao, Vi']
arrayPneumoconiose = ['Pneumoconiose (Silicose, Asbestose, Etc.)','Pneumoconiose (Silic']
arrayQueimaduras = ['Queimadura ou Escaldadura - Efeito de Tempe', 'Queimadura ou Escald','Queimadura Quimica (Lesao de Tecido Provoca','Queimadura Quimica (']

# %%
# Accident_Type
arrayAcidenteTipico = ['TÃ­pico','TÃ­pico','TÃÂ­pico','TÃ¯Â¿Â½pico','TÃ¯Â¿Â½pico']
arrayAcidenteTrajeto = ['Trajeto']
arrayAcidenteDoenca = ['DoenÃÂ§a','DoenÃ§a','DoenÃ§a','DoenÃ¯Â¿Â½a','DoenÃ¯Â¿Â½a']

# %%
# Accident_Causing_Agent
arrayVeiculos = ['Aeronave','Veiculo Aquatico','Veiculo de Terraplen','Veiculo de Terraplenagem','Veiculo Deslisante','Veiculo de Tracao An','Veiculo de Tracao Animal','Veiculo Funicular (Tracao por Cabo)','Veiculos', 'Veiculo, Nic','Veiculo Funicular (T','Veiculo Rodoviario M','Veiculo Rodoviario Motorizado','Veiculo Sobre Trilho','Trator','Transportador com Forca Motriz','Empilhadeira','Rebocador Mecanico, Mula Mecanica','Rebocador Mecanico,','Triciclo','Motocicleta, Motonet', 'Motocicleta, Motoneta','Bicicleta','Transportador com Fo','Transportador por Gr','Transportador por Gravidade','Transportador, Nic','Carro de Mao']
arrayProdutosAlimenticios = ['Carne e Derivados - Inclusive de Origem Anima','Carne e Derivados -','Cereal e Derivados', 'Fruta e Derivados', 'Produto Alimenticio','Produto Alimenticio - Inclusive de Origem Ani','Produtos Alimenticio','Produtos Alimenticios-Inclui Carne,Leite e De','Osso - Produto Anima','Produto Animal, Nic','Animal Vivo','Pena - Produto Animal','Pele, Crina, Pelo, La (Em Bruto) - Produto An','Leite e Derivados - Inclusive de Origem Anima','Leite e Derivados -','Couro Cru ou Curtido - Produto Animal','Couro Cru ou Curtido','Legume, Verdura e De','Legume, Verdura e Derivados','Pele, Crina, Pelo, L','Pena - Produto Anima','Osso - Produto Animal']
arrayFerramentasManuais = ['Alicate, Torques, Tenaz- Ferramenta Manual Se','Alavanca, Pe-De-Cabra- Ferramenta Manual Sem','Alavanca, Pe-De-Cabr','Alicate, Torques, Te','Chave de Porca ou de Abertura Regulavel, Chav','Chave de Porca ou de','Chave de Parafuso- Ferramenta Manual sem Forc','Chave de Parafuso- F','Corda, Cabo, Corrent','Corda, Cabo, Corrente- Ferramenta Manual Sem','Enxada, Enxadao, Sac','Faca, Facao- Ferrame','Ferramenta Manual se','Enxada, Enxadao, Sacho- Ferramenta Manual Sem','Faca, Facao- Ferramenta Manual sem Forca Motr','Ferramenta Manual sem Forca Motriz, Nic','Formao, Cinzel- Ferr','Garfo, Ancinho, Forcado- Ferramenta Manual Se','Garfo, Ancinho, Forc','Lima, Grosa- Ferramenta Manual sem Forca Motr','Lima, Grosa- Ferrame','Formao, Cinzel- Ferramenta Manual sem Forca M','Machadinha, Enxo- Ferramenta Manual sem Forca','Machado - Ferramenta','Machado- Ferramenta Manual sem Forca Motriz','Machado- Ferramenta','Martelo, Malho, Marr','Machadinha, Enxo- Fe','Martelo, Malho, Marreta- Ferramenta Manual Se','Pa, Cavadeira- Ferramenta Manual sem Forca Mo','Picareta- Ferramenta','Picareta- Ferramenta Manual sem Forca Motriz','Plaina- Ferramenta Manual sem Forca Motriz','Plaina- Ferramenta M','Pua, Trado, Verruma,','Pua, Trado, Verruma, Maquina de Furar Manual-','Puncao, Ponteiro, Vazador- Ferramenta Portati','Puncao, Ponteiro, Va','Puncao, Ponteiro, Vazador, Talhadeira- Ferram','Serra, Serrote- Ferramenta Manual sem Forca M','Tesoura, Tesourao- Ferramenta Manual sem Forc']
arrayFerramentasPortateis = ['Cortadeira, Guilhotina- Ferramenta Portatil C','Cortadeira, Guilhoti','Esmeril- Ferramenta Portatil com Forca Motriz','Esmeril- Ferramenta','Ferramenta Acionada','Ferramenta Acionada por Explosivo- Ferramenta','Ferramenta de Soldag','Ferramenta de Soldagem- Ferramenta Portatil C','Ferramenta Portatil com Forca Motriz ou Aquec','Ferro de Passar- Ferramenta Portatil com Forc','Ferro de Passar- Fer','Ferramenta Portatil','Jato de Areia- Ferramenta Portatil com Forca','Jato de Areia- Ferra','Maquina de Aparafusa','Maquina de Aparafusar - Ferramenta Portatil C','Martelete, Socador-','Martelete, Socador- Ferramenta Portatil com F','Masarico - Ferramenta Portatil com Forca Motr','Masarico - Ferrament','Perfuratriz- Ferrame','Perfuratriz- Ferramenta Portatil com Forca Mo','Politriz, Enceradeira- Ferramenta Portatil Co','Politriz, Enceradeir','Rebitadeira- Ferramenta Portatil com Forca Mo','Rebitadeira- Ferrame','Serra, Serrote- Ferr','Serra- Ferramenta Portatil com Forca Motriz O','Talhadeira- Ferramenta Portatil com Forca Mot','Talhadeira- Ferramen']
arrayMobiliarioAcessorio = ['Arquivo, Fichario, Estante - Mobiliario e Ace','Arquivo, Fichario, E','Balcao, Bancada - Mobiliario e Acessorios','Balcao, Bancada - Mo','Cadeira Banco - Mobiliario e Acessorios','Cadeira Banco - Mobi','Luminaria, Globo, Iampada - Mobiliario e Aces','Luminaria, Globo, Ia','Mesa Elastica Desmon','Mesa, Carteira, Exce','Mobiliario e Acessor','Mesa Elastica Desmontavel - Mobiliario e Aces','Mesa, Carteira, Exceto Mesa Elastica Desmonta','Mobiliario e Acessorios, Nic','Tapete, Forracao de','Tapete, Forracao de Piso, Capacho - Mobiliari','Tapete, Forracao de','Tapete, Forracao de Piso, Capacho - Mobiliari']
arraySuperficieEquipamento = ['Asfalto, Alcatrao, Piche','Asfalto, Alcatrao, P','Calcada ou Caminho p','Calcada ou Caminho para Pedestre - Superficie','Escada Movel ou Fixa','Escada Movel ou Fixada, Nic','Escada Permanente Cujos Degraus Permitem Apoi','Chao - superficie ut','Chao - Superficie Ut','Escada Permanente Cu','Chao - Superficie Utilizada para Sustentar Pe','Passarela ou Plataforma Permanentes - Superfi','Passarela ou Platafo','Piso de Andaime e Plataforma Desmontavel - Su','Piso de Mina - Super','Piso de Veiculo - Superficie Utilizada para S','Piso de Andaime e Pl','Piso de Edificio - S','Piso de Edificio - Superficie Utilizada Para','Piso de Mina - Superficie Utilizada para Sust','Piso de Veiculo - Su','Rampa - Superficie U','Rua e Estrada - Supe','Rampa - Superficie Utilizada para Sustentar P','Rua e Estrada - Superficie Utilizada para Sus','Superficie de Susten','Superficie de Sustentacao, Nic - Superficie U']
arrayEdificioEstrutura = ['Andaime, Plataforma - Edificio ou Estrutura','Andaime, Plataforma','Arquibancada, Estadio - Edificio ou Estrutura','Arquibancada, Estadi','Cais, Doca - Edifici','Cais, Doca - Edificio ou Estrutura','Dique, Barragem - Edificio ou Estrutura','Deposito Fixo (Tanque, Silo, Paiol, Etc.) - E','Deposito Fixo (Tanqu','Superficie e Estrutu','Dique, Barragem - Ed','Edificio - Edificio','Edificio ou Estrutur','Edificio - Edificio ou Estrutura','Edificio ou Estrutura (Exceto Piso, Superfici','Escavacao, Fosso, Tu','Canal, Fosso','Escavacao (Para Edificio, Estrada, Etc.)','Escavacao (Para Edif','Ponte, Viaduto - Edi','Ponte, Viaduto - Edificio ou Estrutura','Ponte Rolante - Equi','Ponte Rolante - Equip. de Guindar','Torre, Poste - Edifi','Torre, Poste - Edificio ou Estrutura','Superficie e Estrutura, Nic','Escavacao, Fosso, Tunel, Nic','Poco, Entrada, Galeria, Etc., de Mina','Poco, Entrada, Galer','Telhado','Tunel']
arrayEmbalagemRecipiente = ['Barril, Barrica, Barrilete, Tambor - Embalage','Barril, Barrica, Bar','Caixa, Engradado, Ca','Caixa, Engradado, Caixote - Embalagem, Recipi','Embalagem e Recipien','Embalagem e Recipiente, Vazio ou Cheio, Nic','Frasco, Garrafa - Em','Frasco, Garrafa - Embalagem, Recipiente, Vazi','Tanque, Cilindro (Tr','Tambor, Polia, Rolda','Tambor, Polia, Roldana - Dispositivo de Trans']
arrayDispositivoEnergiaMecanica = ['Correia - Dispositivo de Transmissao de Energ','Corrente, Corda, Cab','Correia - Dispositiv','Dispositivo de Transmissao de Energia Mecanic','Embreagem de Friccao - Dispositivo de Transmi','Corrente, Corda, Cabo - Dispositivo de Transm','Dispositivo de Trans','Dispositivo de trans','Dispositivo de Trans','Embreagem de Friccao','Engrenagem - Disposi','Corrente, Corda, Cab','Engrenagem - Disposi','Engrenagem - Dispositivo de Transmissao de En','Tanque, Cilindro (Transportaveis e nao Sob Pr']
arrayCondicoesAmbientaisAmbiente = ['Aerodispersoides','Area ou Ambiente de','Area ou Ambiente de Trabalho - O Agente do Ac','Exposicao a Pressao','Exposicao a Pressao Ambiente Elevada','Exposicao a Pressao Ambiente Baixa','Particulas - nao Ide','Particulas - nao Identificadas','Pressao Ambiente, Exposicao A','Pressao Ambiente Alt','Pressao Ambiente Alta-Trabalho em Caixao Pneu','Pressao Ambiente Bai','Pressao Ambiente Baixa-Ar Rarefeito','Temperatura Ambiente','Temperatura Ambiente Elevada, Exposicao A','Temperatura Ambiente Baixa, Exposicao A','Temperatura Muito Ba','Temperatura Muito Al','Temperatura Ambiente- nao Inclui a de Objeto','Temperatura Muito Alta, Contato com Objeto Ou','Temperatura Muito Baixa, Contato com Objeto O','Ruido, Exposicao A','Absorcao de Substanc','Absorcao de Substancia Caustica','Ruido','Vibracao, Exposicao A','Vibracao, Exposicao','Ingestao de Substanc','Ingestao de Substancia Caustica...','Inalacao, Ingestao o','Inalacao, Ingestao ou Absorcao, Nic','Poluicao do Solo, Acao Da','Poluicao da Agua, Acao Da','Poluicao, Nic, Exposicao A','Poluicao da Agua, Ac','Poluicao, Nic, Expos','Poluicao do Ar, Acao Da','Poluicao do Ar, Acao','Neblina','Inalacao de Substanc','Inalacao de Substancia Caustica, Toxica ou No']
arrayCompostosQuimicos = ['Acido','Alcali','Alcool','Cianeto ou Composto','Cianeto ou Composto de Cianogenio','Composto Aromatico (Benzol, Toluol, Xilol, A','Composto Aromatico (Benzol, Toluol, Xilol, An','Composto Aromatico (','Composto de Arsenio','Composto de Fosforo','Composto Metalico (D','Composto Metalico (De Chumbo, Mercurio, Zinco','Composto Organico Halogenado (Tricloretileno,','Composto Organico Ha','Dissulfeto de Carbon','Gas Carbonico (Dioxido de Carbono, Co2)','Gas Carbonico (Dioxi','Hidrocarboneto Gasoso (Inclui Gas Liquefeito,','Monoxido de Carbono (Co)','Monoxido de Carbono','Hidrocarboneto Gasos','Nafta e Solvente de','Nafta e Solvente de Nafta (Eter de Petroleo,','Oxidos de Nitrogenio (Vapores Nitrosos)','Oxidos de Nitrogenio','Substancia Quimica,','Substancia Quimica, Material, Produto, Nic','Substancia Quimica, Nic']
arrayEquipamentosGuindar = ['Elevador - Equip. de Guindar','Elevador - Equip. de','Elevador de Cacamba','Elevador de Cacamba para Mineracao - Equipame','Equip. de Guindar, Nic','Equip. de Guindar, N','Guindaste - Equip. d','Pa Mecanica, Draga - Equip. de Guindar','Guincho Eletrico - E','Guincho Pneumatico -','Guindaste - Equip. de Guindar','Guincho Eletrico - Equip. de Guindar','Guincho Pneumatico - Equip. de Guindar','Macaco (Mecanico, Hi','Macaco (Mecanico, Hidraulico, Pneumatico) - E','Pa, Cavadeira- Ferra','Pa Mecanica, Draga -','Pau de Carga - Equip. de Guindar','Pau de Carga - Equip', 'Talha - Equip. de Gu','Talha - Equip. de Guindar']
arrayEquipamentosEletricos = ['Condutor - Equip. Eletrico','Condutor - Equip. El','Equip. Eletrico, Nic','Eletrica, Exposicao','Equip. de Aquecimento Eletrico - Equipam','Equip. de Aqueciment','Equip. de Aqueciment','Equip. Eletrolitico','Equip. Eletrolitico - Equip. Eletri','Equip. Magnetico - E','Equip. Magnetico - Equip. Eletrico','Gerador - Equip. Eletrico','Energia','Eletrica, Exposicao a Energia','Gerador - Equip. Ele','Reostato, Dispositivo de Partida e Aparelho D','Painel de Controle,','Painel de Controle, Barramento, Chave, Interr','Reostato, Dispositiv','Transformador, Conversor - Equip. Eletri','Transformador, Conve']
arrayEquipamentosRadiacao = ['Equip. de Iluminacao','Equip. de Iluminacao - Equip. Emiss','Equip. de Raios X -','Equip. de Raios X - Equip. ou Subst','Equip. Emissor de Ra','Fonte de Radioisotopo - Equip. ou Substa','Arco Eletrico - Equi','Arco Eletrico - Equip. Emissor de Radiac','Equip. ou Substancia','Equip. ou Substancia Emissores de Radiac','Equip. Emissor de Radiacao nao Ionizante','Arco Eletrico','Fonte de Radioisotop','Radiacao Ionizante,','Radiacao Ionizante, Exposicao A','Reator (Inclui Combustivel e Residuo) - Equip','Reator (Inclui Combu','Equip. Emissor de Radiacao nÃ¯Â¿Â½o Ionizante','Equip. Emissor de Radiacao nÃ£o Ionizante','Radiacao nao Ionizan','Radiacao nao Ionizante, Exposicao A']
arrayPetroleoCombustiveis = ['Carvao','Coque','Gas Encanado de Carvao','Gas Encanado de Carv','Gasolina (Exceto Qua','Gasolina (Exceto Quando a Ocorrencia For Caus','Gasoleo, Oleo Diesel','Oleo Combustivel','Parafina, Oleo Lubri','Petroleo Bruto, Bruto Reduzido','Parafina, Oleo Lubrificante e de Corte, Graxa','Produto de Petroleo e de Carvao, Nic','Produto de Petroleo','Petroleo Bruto, Brut','Querosene']
arrayEquipamentosPressaoAnormal = ['Caixao Pneumatico -','Caixao Pneumatico - Equip. para Trabalho','Equip. de Mergulho -','Equip. de Mergulho - Equip. para Tr','Equip. para Trabalho em Ambiente de Pres','Equip. para Trabalho','Escafandro - Equip','Escafandro - Equip.']
arrayMaquinas = ['Britador, Moinho - M','Britador, Moinho - Maquina','Ferramenta, Maquina,','Ferramenta, Maquina, Equip., Veiculo, Ni','Maquina de Embalar o','Furadeira, Broqueadeira, Torno, Freza - Maqui','Furadeira, Broqueade','Laminadora, Calandra','Laminadora, Calandra - Maquina','Maquina Agricola','Maquina de Embalar ou Empacotar','Maquina de Escritorio','Maquina de Escritori','Maquina de Mineracao e Perfuracao (De Tunel,','Maquina de Costurar e de Pespontar','Maquina Textil','Maquina de Mineracao','Maquina, Nic','Misturador, Batedeir','Misturador, Batedeira, Agitador - Maquina','Peneira Mecanica, Maquina Separadora - Maquin','Maquina de Costurar e de Pespontar','Maquina de Costurar','Maquina de Terraplenagem e Construcao de Estr','Maquina de Terraplen','Maquina de Fundir, d','Maquina de Fundir, de Forjar, de Soldar','Maquina de Imprimir','Peneira Mecanica, Ma','Plaina, Tupia - Maqu','Plaina, Tupia - Maquina','Politriz, Lixadora,','Politriz, Lixadora, Esmeril - Maquina','Prensa - Maquina','Serra - Maquina','Tesoura, Guilhotina,','Serra- Ferramenta Po','Tesoura, Guilhotina, Maquina de Cortar - Maqu','Tesoura, Tesourao- F']
arrayCeramica = ['Ceramica','Ceramica, Nic','Louca de Mesa e Outr','Louca de Mesa e Outros Utensilios (De Porcela','Louca Sanitaria (Pia','Tubo, Manilha - Cera','Louca Sanitaria (Pia, Vaso Sanitario, Etc.) -','Tubo, Manilha - Ceramica','Tijolo e Telha - Ceramica','Tijolo e Telha - Cer','Revestimento Ceramic','Revestimento Ceramico (Azulejo, Mosaico, Etc.']
arrayFornosCaldeiras = ['Caldeira','Caldeira, Vaso Sob Pressao, Nic','Caldeira, Vaso Sob P','Forno, Estufa, Retor','Forno, Estufa, Retorta, Aquecedor de Ambiente']
arrayVestuarioTexteis = ['Texteis - Inclui Fib','Texteis - Inclui Fibras Animais Apos O Primei','Vestuario, Nic']
arrayBombasMotoresTurbinas = ['Bomba','Motor (Combustao Int','Motor, Bomba, Turbin','Motor (Combustao Interna, Vapor)','Motor Eletrico - Equip. Eletrico','Motor Eletrico - Equ','Motor, Bomba, Turbina, Nic','Turbina']
arrayAgenteInfeccioso = ['Produto Biologico (Soro, Toxina, Antitoxina,','Produto Biologico (S','Agente Infeccioso ou','Medicamento em Geral (Exceto Produto Biologic','Medicamento em Geral','Agente Infeccioso ou Parasitario - Inclui Bac']
arrayMetaisMinerais = ['Metal - Inclui Liga','Metal - Inclui Liga Ferrosa e nao Ferrosa, Tu','Produto Mineral Metalico - Produto de Minerac','Produto Mineral nao','Produto Mineral Meta','Produto Mineral nao Metalico - Produto de Min']
arrayEquipamentosPressao = ['Vaso Sob Pressao (Para Iiquido, Gas ou Vapor)','Vaso Sob Pressao (Pa','Tubo Sob Pressao (Ma','Tubo Sob Pressao (Mangueira ou Tubo para Iiqu']
arraySerVivo = ['Ataque de Ser Vivo','Ataque de Ser Vivo,','Ataque de Ser Vivo, Nic','Ataque de Ser Vivo com Transmissao de Doenca','Ataque de Ser Vivo c','Ataque de Ser Vivo com Peconha','Ataque de Ser Vivo p','Ataque de Ser Vivo por Mordedura, Picada, Chi','Ser Vivo, Nic']
arrayAprisionamentoQueda = ['Aprision. Em, Sobre ou Entre Objetos Em','Aprision. Em, Sobre ou Entre Dois ou Mai','Aprision. Em, Sobre ou Entre Objeto Para','Aprision. Em, Sobre ou Entre Desabamento','Aprision. Em, Sobre','Aprision. Em, Sob ou','Aprision. Em, Sob ou Entre, Nic','Atrito ou Abrasao, Nic','Atrito ou Abrasao po','Atrito ou Abrasao por Manusear Objeto','Atrito ou Abrasao, N','Atrito ou Abrasao por Objeto em Vibracao','Atrito ou Abrasao por Compressao Repetitiva','Atrito ou Abrasao por Encostar, Pisar, Ajoelh','Atrito ou Abrasao por Corpo Estranho no Olho','Impacto de Pes. Contra Objeto em Movimento','Impacto de Pes. Cont','Impacto de Pes. Contra Objeto Parado','Impacto Sofrido por','Impacto Sofrido por Pes. de Objeto Que Cai','Impacto Sofrido por Pes., Nic','Impacto Sofrido por Pes. de Objeto Projetad','Queda de Pes. com Di','Queda de Pes. em Mes','Queda de Pes. com Dif. de Nivel de And','Queda de Pes. em Mesmo Nivel, Nic','Queda de Pes. em Mesmo Nivel em Passagem Ou','Queda de Pes. com Dif. de Nivel de Vei','Queda de Pes. com Dif. de Nivel, Nic','Queda de Pes. em Mesmo Nivel Sobre ou Contr','Queda de Pes. com Dif. de Nivel em Esc','Queda de Pes. com Dif. de Nivel de Esc','Queda de Pes. com Dif. de Nivel de Mat','Queda de Pes. com Dif. de Nivel em Poc']
arrayMadeira = ['Madeira (Toro, Madei','Madeira (Toro, Madeira Serrada, Pranchao, Pos']
arrayAguaLiquidos = ['Agua - Usar Quando O Estado Iiquido Contribui','Agua - Usar Quando O','Imersao','Liquido, Nic']
arrayVidro = ['Vidraria, Fibra de V','Vidraria, Fibra de Vidro, Lamina, Etc., Excet']
arrayFogoMateriaisInflamaveis = ['Fogo-Chama,Material Incandescente ou Quente,F','Fogo-Chama,Material']
arrayEsfocoExcessivo = ['Esforco Excessivo ao Empurrar ou Puxar Objeto','Esforco Excessivo ao Erguer Objeto','Esforco Excessivo ao Manejar, Sacudir ou Arre','Esforco Excessivo, Nic','Esforco Excessivo ao','Esforco Excessivo, N','Reacao do Corpo a Mo','Reacao do Corpo a Movimento Voluntario','Reacao do Corpo a Movimento Involuntario']
arrayOutros = ['Agente do Acidente I','Agente do Acidente,','Gas e Vapor','Agente do Acidente, Nic','Papel e Pasta para Papel','Papel e Pasta para P','Plastico - Inclui Po','Plastico - Inclui Po, Folha, Trefilado, Barra','Produto de Limpeza, Sabao, Detergente','Produto de Limpeza,','Sucata, Entulho, Res','Sucata, Entulho, Residuo','Vegetal - Planta, Ar','Vegetal - Planta, Arvore, em Estado Natural,']
arrayAgenteNaoEncontrado = ['Agente do Acidente Inexistente']

# %%
# Health Professions
arrayMedico = ['223104','223110', '223115', '223129','223132','223116','223149','223153',' 223124','223156','223101','223102','223103','223105','2231A1','223106','223107','223108','223109','223111','223112','223113','2231F3','223114','223117','223118','223119','223120','223121','223122','223123','223125','223126','223127','223128','223130','223131','2231A2','223133','223134','223135','223136','223137','223138','223139','223140','223141','223142','223143','223144','223145','2231F5','2231F4','223146','223147','223148','223150','223151','223152','223154','223155','223157']
arrayAssisteSocial = ['251605']
arrayFarmaceutico = ['223405','223410']
arrayEfermeiroAuxTecn = ['2235', '322230','322200', '322235','322205','3222E1','322210','322215','322220']
arrayFisioterapeuta = ['22360']
arrayFonoaudiologo = ['223810']
arrayNutricionista = ['223710']
arrayOdontologia = ['223204','223208','223212','223216','223220','223224','223228','223232','223236','223240','223244','223248','223252','223256','223260','223264','223268','223272','2232B1']
arrayPsicologo = ['251510','251515','251540','251530','251505','251520','251535','251525', '251545','251550']
arrayNamesHealthProfessions = ['Medico','Assiste_Social','Farmaceutico','Enfermeiro','Fonoaudiologo','Nutricionista','Odontologia','Psicologo']
arrayNamesHealthProfessionsOrder = ['Assiste_Social','Enfermeiro','Farmaceutico','Fonoaudiologo','Medico','Nutricionista','Odontologia','Psicologo']

# %%
# Accident Indicator
arrayNot = ['NÃ£o','NÃÂ£o','NÃ¯Â¿Â½o','NÃ¯Â¿Â½o']
arrayYes = ['Sim', 'sim']

# %%
def importFiles(fileName):
    dfAccidents = pd.read_csv(fileName+'.csv', sep = ';', encoding='ISO-8859-1')
    return dfAccidents

# %%
def sortDatabase(tableName):
    tableName.columns = ['Agente_Causador_Acidente', 'Data_Acidente', 'CBO', 'CBO_Descricao', 'CID-10', 'CID-10_Descricao', 'CNAE', 'CNAE_Descricao', 'Emitente_CAT', 'Especie_beneficio', 'Filiacao_Segurado', 'obito', 'Munic_Empregador', 'Natureza_Lesao', 'Origem_de_Cadastramento_CAT', 'Parte_Corpo_Atingida', 'Genero', 'Tipo_Acidente', 'UF_Munic_Acidente', 'UF_Munic_Empregador', 'Data_Afastamento', 'Data_Despacho_Beneficio', 'Data_Acidente_Completa', 'Data_Nascimento', 'Data_Emississao_CAT']
    tableName.drop(columns=['CID-10', 'CNAE', 'Data_Acidente']) #'CBO_Descricao'
    return tableName

# %%
def sizeDf(tableName):
    print('Linhas: ' + str(tableName.shape[0]) + ' Colunas: ' +str(tableName.shape[1]))

# %%
def showData(columnName, tableName):
    print()
    dfQuant = tableName[columnName].value_counts()
    print("Tabela Quantidade " + columnName)
    print()
    print(dfQuant)
    print()

# %%
def removeNClass(columnName, tableName):
    countNotClass = tableName[columnName].str.contains('class', na=False).sum() # na = Valor de preenchimento para valores ausentes. 
    #print("Quantidade n class: " + str(countNotClass))
    #print()

    #print("Antes da remoção da ñ class: ")
    #print('Linhas ' + str(tableName.shape[0]) + ' Colunas ' +str(tableName.shape[1]))

    df_remove = tableName.loc[tableName[columnName].str.contains('class', na=False)]
    tableName = tableName.drop(df_remove.index)

    #print("Depois da remoção das ñ class:" )
    #print('Linhas: ' + str(tableName.shape[0]) + ' Colunas: ' +str(tableName.shape[1]))
    #print()
    return tableName

# %%
def removeZero(columnName, tableName):
    count0 = (tableName[columnName] == 0).sum()
    print("Quantidade de 0: " + str(count0))
    print()

    print("Antes da remoção dos 0: ")
    print('Linhas ' + str(tableName.shape[0]) + ' Colunas ' +str(tableName.shape[1]))

    df_remove = tableName.loc[(tableName[columnName] == 0)]
    tableName = tableName.drop(df_remove.index)

    print()
    print("Depois da remoção dos 0:" )
    print('Linhas: ' + str(tableName.shape[0]) + ' Colunas: ' +str(tableName.shape[1]))
    print()
    return tableName

# %%
def separateDateYear(date):
    arrayDate = date.split('/')
    if len(arrayDate) < 3:
        return date
    if arrayDate[2] == '0000':
        print(date)
        return date
    return arrayDate[2]

# %%
def cleanGenre(tableName):
    numRows = tableName.shape[0]
    numColumns = tableName.shape[1]
    df_remove = tableName.loc[(tableName['Genero'].str.contains('class')) 
                                |(tableName['Genero'].str.contains('Informado'))  
                                |(tableName['Genero'].str.contains('Indeterminado'))
                            ]
    tableName = tableName.drop(df_remove.index)
    print('Quant de dados removidos:')
    print('Linhas ' + str(numRows - tableName.shape[0]) + ' Colunas ' +str(numColumns - tableName.shape[1]))
    return tableName

# %%
def cleanCBODescription(tableName):
    #print('cleanCBODescription')
    count= tableName['CBO_Descricao'].str.contains('Informado', na=False).sum() # na = Valor de preenchimento para valores ausentes. 
    #print("Quantidade n Informado: " + str(count))
    #print()

    #print("Antes da remoção da ñ Informado: ")
    #print('Linhas ' + str(tableName.shape[0]) + ' Colunas ' +str(tableName.shape[1]))

    df_remove = tableName.loc[tableName['CBO_Descricao'].str.contains('Informado', na=False)]
    tableName = tableName.drop(df_remove.index)

    #print("Depois da remoção das ñ Informado:" )
    #print('Linhas: ' + str(tableName.shape[0]) + ' Colunas: ' +str(tableName.shape[1]))
    #print()
    return tableName

# %%
def cleanAge(df):
    df_remove = df.loc[(df['Idade'] < 16) | (df['Idade'] > 75)]
    df = df.drop(df_remove.index)
    return df

# %%
def cleanUF(column, tableName):
    #print('cleanUF')
    count= tableName[column].str.contains('Zerado', na=False).sum() # na = Valor de preenchimento para valores ausentes. 
    #print("Quantidade Zerado: " + str(count))
    #print()

    #print("Antes da remoção Zerado: ")
    #print('Linhas ' + str(tableName.shape[0]) + ' Colunas ' +str(tableName.shape[1]))

    df_remove = tableName.loc[tableName[column].str.contains('Zerado', na=False)]
    tableName = tableName.drop(df_remove.index)

    #print("Depois da remoção Zerado:" )
    #print('Linhas: ' + str(tableName.shape[0]) + ' Colunas: ' +str(tableName.shape[1]))
    #print()
    return tableName

# %%
def cleanHealthProfessions(tableName):
    df_remove = tableName.loc[tableName['Profissoes'].str.contains('null', na=False)]
    tableName = tableName.drop(df_remove.index)
    print('Linhas: ' + str(tableName.shape[0]) + ' Colunas: ' +str(tableName.shape[1]))
    return tableName

# %%
def groupsCBO(number):
    
    numberToString = str(number)
    newNumber = int(numberToString[0])
    if newNumber == 0:
        return 'CBO 0' #- MEMBROS DAS FORÇAS ARMADAS'
    elif newNumber == 1:
        return 'CBO 1' #- MEMBROS SUPERIORES DO PODER PÚBLICO'
    elif newNumber == 2:
        return 'CBO 2' #- PROFISSIONAIS DAS CIÊNCIAS E DAS ARTES'
    elif newNumber == 3:
        return 'CBO 3' #- TÉCNICOS DE NÍVEL MÉDIO*'
    elif newNumber == 4:
        return 'CBO 4' #- TRABALHADORES DE SERVIÇOS ADMINISTRATIVOS'
    elif newNumber == 5:
        return 'CBO 5' #- TRABALHADORES DOS SERVIÇOS'
    elif newNumber == 6:
        return 'CBO 6' #- TRABALHADORES AGROPECUÁRIOS'
    elif newNumber == 7:
        return 'CBO 7' #- TRABALHADORES DA PRODUÇÃO'
    elif newNumber == 8:
        return 'CBO 8' #- TRABALHADORES DA PRODUÇÃO'
    elif newNumber == 9:
        return 'CBO 9' #- TRABALHADORES DE REPARAÇÃO E MANUTENÇÃO'
    else:
        return numberToString

# %%
def groupsRegions(word):
    newWord = word.strip()
    if newWord in north:
        return'Norte'
    elif newWord in northeast:
        return 'Nordeste'
    elif newWord in southeast:
        return 'Sudeste'
    elif newWord in midwest:
        return 'Centro_Oeste'
    elif newWord in south:
        return 'Sul'
    else: 
        return newWord

# %%
def groupsPartBody(word):
    newWord = word.strip()
    if newWord in upperLimb:
        return'Membros_Superiores'
    elif newWord in lowerLimb:
        return 'Membros_Inferiores'
    elif newWord in head:
        return 'Cabeca'
    elif newWord in multipleParts:
        return 'Partes_Multiplas'
    elif newWord in bodySystems:
        return 'Sistemas_Aparelhos'
    elif newWord in torso:
        return 'Tronco'
    else: 
        return newWord

# %%
def createDfWithCBOAndGenre(size, valueStart, plusValue, df):
    loop = range(size)
    femaleArray = [0] * size
    masculineArray = [0] * size
    arrayNames = [''] * size

    for index in loop:
        
        femaleArray[index] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(valueStart)) 
                                    & df['Genero'].str.contains('Feminino')].count()
        masculineArray[index] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(valueStart)) 
                                    & df['Genero'].str.contains('Masculino')].count()
       
        arrayNames[index] = 'CBO '  + str(valueStart)
        valueStart = valueStart + plusValue
    dataFrameGenre = {
        "Femenino": femaleArray,
        "Masculino": masculineArray
    }
    newDf=pd.DataFrame(dataFrameGenre,index=arrayNames)
    return newDf

# %%
def createDfWithCBOSAndYears(df):
    loopCBO = range(10)
    loopYear = range(5)
    CBO = 0
    year = 2018
    dataFrameYear = {
        "2018":[],
        "2019":[],
        "2020":[],
        "2021":[],
        "2022":[]
    }
    
    for indexYear in loopYear:
        CBO = 0
        newArray = [0] * 10
        for indexCBO in loopCBO:
            newArray[indexCBO] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(CBO)) 
                                & df['Ano_Acidente'].str.contains(str(year))].count()
            CBO = CBO + 1
        dataFrameYear[str(year)] = newArray
        year = year +1
    newDf=pd.DataFrame(dataFrameYear,
                index=['CBO 0' , 'CBO 1' , 'CBO 2' , 'CBO 3', 'CBO 4' , 'CBO 5' , 'CBO 6' , 'CBO 7', 'CBO 8', 'CBO 9']
            )
    return newDf

# %%
def createDfWhithCBOAndYears(df, numberCBO):
    loop = range(5)
    arrayCBO = [0] * 5
    arrayNames = [''] * 5
    year = 2018

    for index in loop:
        arrayCBO[index] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(numberCBO)) 
                                & df['Ano_Acidente'].str.contains(str(year))].count()
        arrayNames[index] = str(year) 
        year = year +1

        
    newDataFrameYear = {
        "CBO " + str(numberCBO): arrayCBO,
    }
    newDf=pd.DataFrame(newDataFrameYear,
                index=arrayNames
            )
    return newDf

# %%
def createDfWhithCBOSAndYear(df, year):
    loop = range(10)
    arrayCBO = [0] * 10
    arrayNames = [''] * 10
    CBO = 0

    for index in loop:
        arrayCBO[index] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(CBO)) 
                                & df['Ano_Acidente'].str.contains(str(year))].count()
        arrayNames[index] = 'CBO ' + str(CBO) 
        CBO = CBO +1

        
    newDataFrameYear = {
        year: arrayCBO,
    }
    newDf=pd.DataFrame(newDataFrameYear,
                index=arrayNames
            )
    return newDf

# %%
def createDfWhithBodyPartAndCBO(numberCBO, df):
    loop = range(6)
    arrayCBO = [0] * 6
    arrayNames = [''] * 6

    for index in loop:
        arrayCBO[index] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(numberCBO)) 
                                & df['Parte_Corpo_Atingida'].str.contains(arrayNameGroupPart[index])].count()
        arrayNames[index] =  arrayNameGroupPart[index]
        
    newDataFrameYear = {
        "CBO " + str(numberCBO): arrayCBO,
    }
    newDf=pd.DataFrame(newDataFrameYear,
                index=arrayNames
            )
    return newDf

# %%
def createDfWhithBodyPartAndCBOS(df):
    loopBodyPart = range(6)
    loopCBO = range(10)
    CBO = 0
    arrayCBO = [0] * 6
    arrayNames = [''] * 6

    dataBodyPart = {
        "Cabeca":[],
        "Membros_Inferiores":[],
        "Partes_Multiplas":[],
        "Sistemas_Aparelhos":[],
        "Tronco":[]
    }

    for index in loopBodyPart:
        CBO = 0
        newArray = [0] * 10
        for indexCBO in loopCBO:
            newArray[indexCBO] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(CBO)) 
                                & df['Parte_Corpo_Atingida'].str.contains(arrayNameGroupPart[index])].count()
            CBO = CBO + 1
        dataBodyPart[arrayNameGroupPart[index]] = newArray
            
    newDf=pd.DataFrame(dataBodyPart,
                index=['CBO 0' , 'CBO 1' , 'CBO 2' , 'CBO 3', 'CBO 4' , 'CBO 5' , 'CBO 6' , 'CBO 7', 'CBO 8', 'CBO 9']
            )
    return newDf

# %%
def createDfWhithUFAndCBO(numberCBO, df):
    loop = range(5)
    arrayCBO = [0] * 5
    arrayNames = [''] * 5

    for index in loop:
        arrayCBO[index] = df['CBO'].loc[df['CBO'].str.contains('CBO '+ str(numberCBO)) 
                                & df['UF_Munic_Acidente'].str.contains(arrayRegions[index])].count()
        arrayNames[index] =  arrayRegions[index]
        
    newDataFrameYear = {
        "CBO " + str(numberCBO): arrayCBO,
    }
    newDf=pd.DataFrame(newDataFrameYear,
                index=arrayNames
            )
    return newDf

# %%
def createDFForAgeAndGenre(size, valueStart, columnName, plusValue, df):
    loop = range(size)
    femaleArray = [0] * size
    masculineArray = [0] * size
    arrayNames = [''] * size

    for index in loop:
        femaleArray[index] = df[columnName].loc[(df[columnName].astype(int) > valueStart) 
                            & (df[columnName].astype(int) < (valueStart + plusValue)) 
                            & df['Genero'].str.contains('Feminino')].count()
        masculineArray[index] = df[columnName].loc[(df[columnName].astype(int) > valueStart) 
                                & (df[columnName].astype(int) < (valueStart + plusValue)) 
                                & df['Genero'].str.contains('Masculino')].count()
        arrayNames[index] = str(valueStart) + " á " + str(valueStart + plusValue)
        valueStart = valueStart + plusValue
    dataFrameGenre = {
        "Femenino": femaleArray,
        "Masculino": masculineArray
    }
    df=pd.DataFrame(dataFrameGenre,index=arrayNames)
    return df

# %%
def createColumnAge(born):
    if type(born) is str and ('class' in born) == False: 
        arrayBorn = born.split('/')
        if len(arrayBorn) == 3:
            if arrayBorn[2] != '0000':
                born = datetime.strptime(born, "%d/%m/%Y").date()
                today = date.today()
                return today.year - born.year - ((today.month, today.day) < (born.month, born.day))
    return -100

# %%
def groupsNatureInjury(word):
    newWord = word.strip()
    if newWord in arrayAmputacao:
        return 'Amputacao ou enucleacao'
    elif newWord in arrayAsfixia:
        return 'Asfixia, estrangulamento e afogamento'
    elif newWord in arrayChoque:
        return 'Choque eletrico e eletroplessao'
    elif newWord in arrayConcussao:
        return 'Concussao cerebral'
    elif newWord in arrayCongelamento:
        return 'Congelamento e geladura'
    elif newWord in arrayContusao:
        return 'Contusao e esmagamento'
    elif newWord in arrayCortes:
        return 'Corte, laceracao'
    elif newWord in arrayDermatose:
        return 'Dermatose'
    elif newWord in arrayDistensao:
        return 'Distensao e torcao'
    elif newWord in arrayDoencas:
        return 'Doenca'
    elif newWord in arrayRadiacao:
        return 'Efeito de radiacao'
    elif newWord in arrayEnvenenamento:
        return 'Envenenamento sistemico'
    elif newWord in arrayEscoriacao:
        return 'Escoriacao e abrasão'
    elif newWord in arrayEsforco:
        return 'Esforco excessivo'
    elif newWord in arrayFratura:
        return 'Fratura'
    elif newWord in arrayHernia:
        return 'Hernia'
    elif newWord in arrayInflamacao:
        return 'Inflamacao'
    elif newWord in arrayIntermacao:
        return 'Intermacao'
    elif newWord in arrayLesoes:
        return 'Lesoes'
    elif newWord in arrayLuxacao:
        return 'Luxacao'
    elif newWord in arrayPerdaSentidos:
        return 'Perda dos Sentidos'
    elif newWord in arrayPneumoconiose:
        return 'Pneumoconiose'
    elif newWord in arrayQueimaduras:
        return 'Queimaduras'
    else: 
        return newWord

# %%
def groupsAccidentType(word):
    newWord = word.strip()
    if newWord in arrayAcidenteTipico:
        return'Tipico'
    elif newWord in arrayAcidenteTrajeto:
        return 'Trajeto'
    elif newWord in arrayAcidenteDoenca:
        return 'Doenca'
    else: 
        return 'Tipico'

# %%
def groupGenre(word):
    newWord = str(word).strip()
    if newWord.find('nformado') != -1:
        return 'Nao Informado'
    else:
        return newWord

# %%
def groupsAccidentCausingAgent(word):
    newWord = word.strip()
    if newWord in arrayVeiculos:
        return 'Veiculos e equipamentos de transporte'
    elif newWord in arrayProdutosAlimenticios:
        return 'Produtos alimenticios e/ou de origem animal'
    elif newWord in arrayFerramentasManuais:
        return 'Ferramentas manuais sem forCa motriz'
    elif newWord in arrayFerramentasPortateis:
        return 'Ferramentas portateis com forca motriz ou aquecimento'
    elif newWord in arrayMobiliarioAcessorio:
        return 'Mobiliario e acessorios'
    elif newWord in arraySuperficieEquipamento:
        return 'Edificio ou estrutura'
    elif newWord in arrayEdificioEstrutura:
        return 'Superficies e equipamentos utilizados para sustentar pessoas'
    elif newWord in arrayEmbalagemRecipiente:
        return 'Embalagem ou recipiente (vazio ou cheio)'
    elif newWord in arrayDispositivoEnergiaMecanica:
        return 'Dispositivo de transmissao de energia mecanica'
    elif newWord in arrayCondicoesAmbientaisAmbiente:
        return 'Condicoes ambientais ou do ambiente'
    elif newWord in arrayCompostosQuimicos:
        return 'Compostos e/ou subtancias quimicas'
    elif newWord in arrayEquipamentosRadiacao:
        return 'Equipamentos ou subtancias emissoras de radiacao'
    elif newWord in arrayEquipamentosGuindar:
        return 'Equipamentos de guindar'
    elif newWord in arrayEquipamentosEletricos:
        return 'Equipamentos eletricos'
    elif newWord in arrayPetroleoCombustiveis:
        return 'Petroleo, combustíveis e derivados'
    elif newWord in arrayEquipamentosPressaoAnormal:
        return 'Equipamentos para trabalho em ambiente de pressão anormal'
    elif newWord in arrayMaquinas:
        return 'Maquinas'
    elif newWord in arrayCeramica:
        return 'Ceramica, utensilios e materiais derivados'
    elif newWord in arrayFornosCaldeiras:
        return 'Fornos e caldeiras'
    elif newWord in arrayVestuarioTexteis:
        return 'Vestuario e texteis'
    elif newWord in arrayAgenteInfeccioso:
        return 'Agente infeccioso, produto biologico e medicamentos'
    elif newWord in arrayBombasMotoresTurbinas:
        return 'Bombas, motores e turbinas'
    elif newWord in arrayMetaisMinerais:
        return 'Metais e minerais'
    elif newWord in arrayEquipamentosPressao:
        return 'Equipamentos sob pressao'
    elif newWord in arraySerVivo:
        return 'Ser vivo'
    elif newWord in arrayAprisionamentoQueda:
        return 'Aprisionamento, atrito, abrasao, impacto ou queda'
    elif newWord in arrayMadeira:
        return 'Madeira'
    elif newWord in arrayAguaLiquidos:
        return 'Agua e liquidos'
    elif newWord in arrayVidro:
        return 'Vidro'
    elif newWord in arrayFogoMateriaisInflamaveis:
        return 'Fogo e materiais inflamaveis'
    elif newWord in arrayEsfocoExcessivo:
        return 'Esfoco excessivo e movimentos involuntarios'
    elif newWord in arrayOutros:
        return 'Outros'
    elif newWord in arrayAgenteNaoEncontrado:
        return 'Agente do Acidente Inexistente'
    else: 
        return newWord

# %%
def groupsHealthProfessions(word):
    newWord = str(word).strip()
    if newWord in arrayMedico:
        return 'Medico'
    if newWord in arrayAssisteSocial:
        return 'Assiste_Social'
    if newWord in arrayFarmaceutico:
        return 'Farmaceutico'
    if newWord in arrayEfermeiroAuxTecn:
        return 'Enfermeiro'
    if newWord in arrayFisioterapeuta:
        return 'Fisioterapeuta'
    if newWord in arrayFonoaudiologo:
        return 'Fonoaudiologo'
    if newWord in arrayNutricionista:
        return 'Nutricionista'
    if newWord in arrayOdontologia:
        return 'Odontologia'
    if newWord in arrayPsicologo:
        return 'Psicologo'
    else: 
        if len(newWord) > 4 and newWord[0] + newWord[1] + newWord[2] + newWord[3] == "2235": #Enfermeiro
            return 'Enfermeiro'
        return 'null'

# %%
def createDfWithHealthProfessionsAndGenre(df):
    size = len(arrayNamesHealthProfessions)
    loop = range(size)
    femaleArray = [0] * size
    masculineArray = [0] * size

    for index in loop:
        
        femaleArray[index] = df['Profissoes'].loc[df['Profissoes'].str.contains(arrayNamesHealthProfessions[index]) 
                                    & df['Genero'].str.contains('Feminino')].count()
        masculineArray[index] = df['Profissoes'].loc[df['Profissoes'].str.contains(arrayNamesHealthProfessions[index]) 
                                    & df['Genero'].str.contains('Masculino')].count()
    dataFrameGenre = {
        "Femenino": femaleArray,
        "Masculino": masculineArray
    }
    newDf=pd.DataFrame(dataFrameGenre,index=arrayNamesHealthProfessions)
    return newDf

# %%
def createDfWhithBodyPartAndHealthProfessions(df):
    sizeHealthProfessions = len(arrayNamesHealthProfessions)
    sizeBodyPart = len(arrayNameGroupPart)
    loopBodyPart = range(sizeBodyPart)
    loopHealthProfessions = range(sizeHealthProfessions)
    arrayHealthProfessions= [0] * sizeBodyPart
    arrayNames = [''] * sizeBodyPart

    dataBodyPart = {
        "Cabeca":[],
        "Membros_Inferiores":[],
        "Partes_Multiplas":[],
        "Sistemas_Aparelhos":[],
        "Tronco":[]
    }

    for index in loopBodyPart:
        newArray = [0] * sizeHealthProfessions
        for indexHealthProfessions in loopHealthProfessions:
            newArray[indexHealthProfessions] = df['Profissoes'].loc[df['Profissoes'].str.contains(str(arrayNamesHealthProfessions[indexHealthProfessions])) 
                                & df['Parte_Corpo_Atingida'].str.contains(arrayNameGroupPart[index])].count()
        dataBodyPart[arrayNameGroupPart[index]] = newArray
            
    newDf=pd.DataFrame(dataBodyPart,
                index=arrayNamesHealthProfessions
            )
    return newDf

# %%
def createDfWhithHealthProfessionsAndYear(df):
    sizeHealthProfessions = len(arrayNamesHealthProfessions)
    loopHealthProfessions = range(sizeHealthProfessions)
    loopYear = range(5)
    year = 2018
    dataFrameYear = {
        "2018":[],
        "2019":[],
        "2020":[],
        "2021":[],
        "2022":[]
    }
    
    for indexYear in loopYear:
        newArray = [0] * sizeHealthProfessions
        for indexHealthProfessions in loopHealthProfessions:
            newArray[indexHealthProfessions] = df['Profissoes'].loc[df['Profissoes'].str.contains(arrayNamesHealthProfessions[indexHealthProfessions]) 
                                & df['Ano_Acidente'].str.contains(str(year))].count()
        dataFrameYear[str(year)] = newArray
        year = year +1
    newDf=pd.DataFrame(dataFrameYear,
                index=arrayNamesHealthProfessions
            )
    return newDf

# %%
def changeGenreToNumber(word):
    newWord = str(word).strip()
    if newWord in 'Feminino':
        return 0
    if newWord in 'Masculino':
        return 1
    else: 
        return word

# %%
def changeAccidentCausingAgentToNumber(word):
    newWord = word.strip()
    if newWord in 'Veiculos e equipamentos de transporte':
        return 0
    elif newWord in 'Produtos alimenticios e/ou de origem animal':
        return 1
    elif newWord in 'Ferramentas manuais sem forCa motriz':
        return 2
    elif newWord in 'Ferramentas portateis com forca motriz ou aquecimento':
        return 3
    elif newWord in 'Mobiliario e acessorios':
        return 4
    elif newWord in 'Superficies e equipamentos utilizados para sustentar pessoas':
        return 5
    elif newWord in 'Edificio ou estrutura':
        return 6
    elif newWord in 'Embalagem ou recipiente (vazio ou cheio)':
        return 7
    elif newWord in 'Dispositivo de transmissao de energia mecanica':
        return 8
    elif newWord in 'Condicoes ambientais ou do ambiente':
        return 9
    elif newWord in 'Compostos e/ou subtancias quimicas':
        return 10
    elif newWord in 'Equipamentos de guindar':
        return 11
    elif newWord in 'Equipamentos eletricos':
        return 12
    elif newWord in 'Equipamentos ou subtancias emissoras de radiacao':
        return 13
    elif newWord in 'Petroleo, combustíveis e derivados':
        return 14
    elif newWord in 'Equipamentos para trabalho em ambiente de pressão anormal':
        return 15
    elif newWord in 'Maquinas':
        return 16
    elif newWord in 'Ceramica, utensilios e materiais derivados':
        return 17
    elif newWord in 'Fornos e caldeiras':
        return 18
    elif newWord in 'Vestuario e texteis':
        return 19
    elif newWord in 'Bombas, motores e turbinas':
        return 20
    elif newWord in 'Agente infeccioso, produto biologico e medicamentos':
        return 21
    elif newWord in 'Metais e minerais':
        return 22
    elif newWord in 'Equipamentos sob pressao':
        return 23
    elif newWord in 'Ser vivo':
        return 24
    elif newWord in 'Aprisionamento, atrito, abrasao, impacto ou queda':
        return 25
    elif newWord in 'Madeira':
        return 26
    elif newWord in 'Agua e liquidos':
        return 27
    elif newWord in 'Vidro':
        return 28
    elif newWord in 'Fogo e materiais inflamaveis':
        return 29
    elif newWord in 'Esfoco excessivo e movimentos involuntarios':
        return 30
    elif newWord in  'Outros':
        return 31
    elif newWord in 'Agente do Acidente Inexistente':
        return 32
    else: 
        return newWord

# %%
def changeAccidentIndicatorToNumber(word):
    newWord = str(word).strip()
    if newWord in arrayNot:
        return 0
    if newWord in arrayYes:
        return 1
    return newWord

# %%
def changeNatureInjuryToNumber(word):
    newWord = word.strip()
    if newWord in 'Amputacao ou enucleacao':
        return 0
    elif newWord in 'Asfixia, estrangulamento e afogamento':
        return 1
    elif newWord in 'Choque eletrico e eletroplessao':
        return 2
    elif newWord in 'Concussao cerebral':
        return 3
    elif newWord in 'Congelamento e geladura':
        return 4
    elif newWord in 'Contusao e esmagamento':
        return 5
    elif newWord in 'Corte, laceracao':
        return 6
    elif newWord in 'Dermatose':
        return 7
    elif newWord in 'Distensao e torcao':
        return 8
    elif newWord in 'Doenca':
        return 9
    elif newWord in 'Efeito de radiacao':
        return 10
    elif newWord in 'Envenenamento sistemico':
        return 11
    elif newWord in  'Escoriacao e abrasão':
        return 12
    elif newWord in 'Esforco excessivo':
        return 13
    elif newWord in 'Fratura':
        return 14
    elif newWord in 'Hernia':
        return 15
    elif newWord in 'Inflamacao':
        return 16
    elif newWord in 'Intermacao':
        return 17
    elif newWord in 'Lesoes':
        return 18
    elif newWord in 'Luxacao':
        return 19
    elif newWord in 'Perda dos Sentidos':
        return 20
    elif newWord in 'Pneumoconiose':
        return 21
    elif newWord in 'Queimaduras':
        return 22
    else: 
        return newWord

# %%
def changePartBodyToNumber(word):
    newWord = word.strip()
    size = len(arrayNameGroupPart)
    for index in range(size):
        if word in arrayNameGroupPart[index]:
            newWord = index
    return newWord

# %%
def changeAccidentTypeToNumber(word):
    newWord = word.strip()
    if newWord in 'Doenca':
        return 0
    elif newWord in 'Tipico':
        return 1
    elif newWord in 'Trajeto':
        return 2
    else: 
        return newWord

# %%
def changeHealthProfessionsToNumber(word):
    newWord = word.strip()
    size = len(arrayNamesHealthProfessionsOrder)
    for index in range(size):
        if word in arrayNamesHealthProfessionsOrder[index]:
            newWord = index
    return newWord

# %%
def changeAgeToNumber(word):
    newWord = str(word).strip()
    value = 16
    for index in range(6):
        if word >= value and word < (value + 10):
            newWord = index
       
        value = value + 10
    return newWord
