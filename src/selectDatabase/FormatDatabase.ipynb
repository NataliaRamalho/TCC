# %%
import numpy as np
import pandas as pd

# %%
def removeDescription(data):
    newArrayData = data.split('-')
    if 'class' in newArrayData[0]:
        return newArrayData[0]
    return int(newArrayData[0])

# %%
def formatData(filePath):
    # Create variables 
    fileType = ''

    oldType = ['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
        'Data Nascimento', 'Data Emissão CAT']
    
    oldTypeModel2=['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
        'Emitente CAT', 'Espï¿½cie do benefï¿½cio', 'Filiaï¿½ï¿½o Segurado',
        'Indica acidente', 'Munic Empr', 'Natureza da Lesï¿½o',
        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
        'Data  Afastamento', 'Data Despacho Benefï¿½cio', 'Data Acidente.1',
        'Data Nascimento', 'Data Emissï¿½o CAT']
    
    oldTypeModel3=['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
        'Indica acidente', 'Munic Empr', 'Natureza da Lesão',
        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
        'Data Nascimento', 'Data Emissão CAT']
    
    oldTypeModel4=['ï»¿Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO_1',
        'CID-10', 'CID-10_2', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador_3',
        'Emitente CAT', 'EspÃ©cie do benefÃ­cio', 'FiliaÃ§Ã£o Segurado',
        'Indica acidente', 'Munic Empr', 'Natureza da LesÃ£o',
        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
        'Data  Afastamento', 'Data Despacho BenefÃ­cio', 'Data Acidente_4',
        'Data Nascimento', 'Data EmissÃ£o CAT']
    
    recentType = ['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CID-10',
        'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1', 'Emitente CAT',
        'Espécie do benefício', 'Filiação Segurado', 'Indica Óbito Acidente',
        'Munic Empr', 'Natureza da Lesão', 'Origem de Cadastramento CAT',
        'Parte Corpo Atingida', 'Sexo', 'Tipo do Acidente',
        'UF  Munic.  Acidente', 'UF Munic. Empregador', 'Data Acidente.1',
        'Data Despacho Benefício', 'Data Acidente.2', 'Data Nascimento',
        'Data Emissão CAT', 'CNPJ/CEI Empregador']
    
    recentTypeModel2 = ['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CID-10',
        'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1', 'Emitente CAT',
        'Espï¿½cie do benefï¿½cio', 'Filiaï¿½ï¿½o Segurado',
        'Indica ï¿½bito Acidente', 'Munic Empr', 'Natureza da Lesï¿½o',
        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
        'Data Acidente.1', 'Data Despacho Benefï¿½cio', 'Data Acidente.2',
        'Data Nascimento', 'Data Emissï¿½o CAT', 'CNPJ/CEI Empregador']
    
    # Get file
    df = pd.read_csv(filePath+'.csv', sep = ';', encoding='ISO-8859-1')

    # Define Type
    if np.array_equal(oldType,df.columns) or np.array_equal(oldTypeModel2,df.columns) or np.array_equal(oldTypeModel3,df.columns) or np.array_equal(oldTypeModel4,df.columns):
        fileType = 'oldType'
    elif np.array_equal(recentType,df.columns) or np.array_equal(recentTypeModel2,df.columns):
        fileType = 'recentType' 

    # Rename columns oldType 
    if fileType == 'oldType':
        df.columns = ['Agente  Causador  Acidente', 'Data Acidente', 'CBO', 'CBO.1', 'CID-10',
        'CID-10.1', 'CNAE2.0 Empregador', 'CNAE2.0 Empregador.1',
        'Emitente CAT', 'Espécie do benefício', 'Filiação Segurado',
        'Indica Óbito Acidente', 'Munic Empr', 'Natureza da Lesão',
        'Origem de Cadastramento CAT', 'Parte Corpo Atingida', 'Sexo',
        'Tipo do Acidente', 'UF  Munic.  Acidente', 'UF Munic. Empregador',
        'Data  Afastamento', 'Data Despacho Benefício', 'Data Acidente.1',
        'Data Nascimento', 'Data Emissão CAT']

    # Remove column CNPJ/CEI Empregador for recentType
    if fileType == 'recentType':
        df = df.drop(columns=['CNPJ/CEI Empregador'])

    # Remove column Data Acidente.1
    if fileType == 'recentType':
        df = df.drop(columns=['Data Acidente.1'])

    #Create Column "CBO2"
    if fileType == 'oldType':
        df['CBO2'] = df['CBO.1'].apply(removeDescription)
        df['CBO'] = df['CBO.1']
        df = df.drop(columns=['CBO.1'])
    elif fileType == 'recentType':
        df['CBO2'] = df['CBO'].apply(removeDescription)

    # Create Column Column "CID-10_Descricao" and remove CID-10.1
    if fileType == 'recentType':
        df['CID-10_Descricao'] = df['CID-10']

    # Create Column 'Data_afastamento'
    if fileType == 'recentType':
        df['Data_Afastamento'] = 0
    
    #Rename columns
    if fileType == 'oldType':
        df.columns = ['Agente_Causador_Acidente', 'Data_Acidente', 'CBO_Descricao', 'CID-10','CID-10_Descricao','CNAE', 'CNAE_Descricao','Emitente_CAT', 'Especie_beneficio', 'Filiacao_Segurado', 'obito', 'Munic_Empregador', 'Natureza_Lesao', 'Origem_de_Cadastramento_CAT', 'Parte_Corpo_Atingida', 'Genero', 'Tipo_Acidente', 'UF_Munic_Acidente', 'UF_Munic_Empregador', 'Data_Afastamento', 'Data_Despacho_Beneficio', 'Data_Acidente_Completa', 'Data_Nascimento', 'Data_Emississao_CAT', 'CBO']
    elif fileType == 'recentType':
        df.columns = ['Agente_Causador_Acidente', 'Data_Acidente', 'CBO_Descricao','CID-10', 'CNAE', 'CNAE_Descricao','Emitente_CAT', 'Especie_beneficio', 'Filiacao_Segurado','obito', 'Munic_Empregador', 'Natureza_Lesao', 'Origem_de_Cadastramento_CAT', 'Parte_Corpo_Atingida', 'Genero', 'Tipo_Acidente', 'UF_Munic_Acidente', 'UF_Munic_Empregador', 'Data_Despacho_Beneficio', 'Data_Acidente_Completa', 'Data_Nascimento', 'Data_Emississao_CAT', 'CBO','CID-10_Descricao','Data_Afastamento']

    #Sorted columns
    if fileType ==  'oldType' or fileType ==  'recentType':
        df = df[['Agente_Causador_Acidente', 'Data_Acidente', 'CBO', 'CBO_Descricao', 'CID-10', 'CID-10_Descricao', 'CNAE', 'CNAE_Descricao', 'Emitente_CAT', 'Especie_beneficio', 'Filiacao_Segurado', 'obito', 'Munic_Empregador', 'Natureza_Lesao', 'Origem_de_Cadastramento_CAT', 'Parte_Corpo_Atingida', 'Genero', 'Tipo_Acidente', 'UF_Munic_Acidente', 'UF_Munic_Empregador', 'Data_Afastamento', 'Data_Despacho_Beneficio', 'Data_Acidente_Completa', 'Data_Nascimento', 'Data_Emississao_CAT']]

    return df
